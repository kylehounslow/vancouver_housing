# %%
import time
from tqdm import tqdm
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from geopy import Nominatim
import geojson
import folium
from branca.colormap import LinearColormap, StepColormap

# %matplotlib inline

# %% [markdown]
# ## Let's load the data and have a peek at the contents

# %%
df = pd.read_csv('./data/round3/rew_round3_with_latlng.csv')
df.head()
# Out:
#                      address    price  \
# 0        405-12 Athletes Way   999000
# 1    604-1661 Ontario Street  1398000
# 2      204-1529 W 6th Avenue   699000
# 3      106-1551 Mariner Walk   929000
# 4  1103-1783 Manitoba Street   859000
#
#                                                 link  bed  bath  sqft   age  \
# 0  https://www.rew.ca/properties/R2219336/405-12-...    2     1   884   8.0
# 1  https://www.rew.ca/properties/R2221859/604-166...    2     2  1189   9.0
# 2  https://www.rew.ca/properties/R2220891/204-152...    0     1   719  21.0
# 3  https://www.rew.ca/properties/R2222093/106-155...    2     2  1094  29.0
# 4  https://www.rew.ca/properties/R2222252/1103-17...    2     1   714   3.0
#
#    gross_taxes_2017  strata_maintenance_fees            area     sub_area  \
# 0            2153.0                    516.0  Vancouver West  False Creek
# 1            2721.0                    679.0  Vancouver West  False Creek
# 2            1456.0                    361.0  Vancouver West  False Creek
# 3            1983.0                    493.0  Vancouver West  False Creek
# 4            2018.0                    361.0  Vancouver West  False Creek
#
#   property_type               strata_type listing_id  \
# 0     Apt/Condo           Freehold Strata   R2219336
# 1     Apt/Condo           Freehold Strata   R2221859
# 2     Apt/Condo           Freehold Strata   R2220891
# 3     Apt/Condo  Leasehold prepaid-Strata   R2222093
# 4     Apt/Condo           Freehold Strata   R2222252
#
#                    primary_broker  \
# 0           Team 3000 Realty Ltd.
# 1  Trg The Residential Group Rlty
# 2                Macdonald Realty
# 3       Engel & Volkers Vancouver
# 4   Sutton Grp West Coast (Brdwy)
#
#                                             features  \
# 0  Air Conditioning, ClthWsh/Dryr/Frdg/Stve/DW, M...
# 1               ClthWsh/Dryr/Frdg/Stve/DW, Microwave
# 2                     Dishwasher, Garage Door Opener
# 3  ClthWsh/Dryr/Frdg/Stve/DW, Disposal - Waste, D...
# 4  ClthWsh/Dryr/Frdg/Stve/DW, Disposal - Waste, D...
#
#                                            amenities  \
# 0  Club House, Elevator, Exercise Centre, Garden,...
# 1  Bike Room, Exercise Centre, In Suite Laundry, ...
# 2   Elevator, Restaurant, Storage, Wheelchair Access
# 3        Elevator, Garden, In Suite Laundry, Storage
# 4  Bike Room, Club House, Elevator, Exercise Cent...
#
#                                          school_info                    latlng
# 0  [{'name': 'Simon Fraser Elementary School', 'a...  (49.271554, -123.106738)
# 1  [{'name': 'Simon Fraser Elementary School', 'a...                   MISSING
# 2  [{'name': 'Henry Hudson Elementary School', 'a...                   MISSING
# 3  [{'name': 'Henry Hudson Elementary School', 'a...                   MISSING
# 4  [{'name': 'Simon Fraser Elementary School', 'a...                   MISSING

# %%
df.columns
# Out:
# Index(['address', 'price', 'link', 'bed', 'bath', 'sqft', 'age',
#        'gross_taxes_2017', 'strata_maintenance_fees', 'area', 'sub_area',
#        'property_type', 'strata_type', 'listing_id', 'primary_broker',
#        'features', 'amenities', 'school_info', 'latlng'],
#       dtype='object')

# %% [markdown]
# ## Let's organize our variables into numerical (quantitative) and categorical (qualitative)

# %%
quantitative_vars = ['price', 
                     'bed', 
                     'bath', 
                     'sqft', 
                     'age', 
                     'gross_taxes_2017', 
                     'strata_maintenance_fees']
qualitative_vars = ['address', 
                    'area', 
                    'sub_area', 
                    'property_type', 
                    'strata_type', 
                    'primary_broker', 
                    'features', 
                    'amenities', 
                    'school_info', 
                    'latlng']
other_vars = ['link', 
              'listing_id']

# %% [markdown]
# ## Get stats for all of the data

# %%
df.describe()
# Out:
#               price         bed        bath          sqft         age  \
# count  7.210000e+02  721.000000  721.000000    721.000000  712.000000
# mean   2.754739e+06    3.490985    2.950069   2139.233010   30.612360
# std    3.103278e+06    2.011837    1.776468   1547.853616   32.038457
# min    2.250000e+05    0.000000    0.000000      0.000000    0.000000
# 25%    1.049000e+06    2.000000    2.000000   1039.000000    3.000000
# 50%    1.848888e+06    3.000000    3.000000   1820.000000   19.500000
# 75%    3.358800e+06    5.000000    4.000000   2852.000000   50.000000
# max    3.500000e+07   10.000000    8.000000  12619.000000  113.000000
#
#        gross_taxes_2017  strata_maintenance_fees
# count        647.000000               346.000000
# mean        5685.330757               421.225434
# std         5677.014141               619.160138
# min            0.000000                 0.000000
# 25%         1806.500000               245.250000
# 50%         4477.000000               361.000000
# 75%         7797.000000               461.000000
# max        58986.000000              9999.000000

# %% [markdown]
# ## Wow, very large maximum albeit not suprising.  Let's have a closer look at the distribution of pricing

# %%
df.price.describe()
# Out:
# count    7.210000e+02
# mean     2.754739e+06
# std      3.103278e+06
# min      2.250000e+05
# 25%      1.049000e+06
# 50%      1.848888e+06
# 75%      3.358800e+06
# max      3.500000e+07
# Name: price, dtype: float64

# %% [markdown]
# ### Plot histogram of prices

# %%
def plot_prices(df: pd.DataFrame, bins: list):
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    fig, ax = plt.subplots()
    ax.set_xticks(bins)
    plt.xticks(rotation='vertical')
    return sns.distplot(df.price, bins=bins)

bins = range(int(df.price.min()),int(df.price.max()),1000000)
plot_prices(df, bins)

# %% [markdown]
# ### Definitely a skewed distribution, looks as if we have a few outliers at the higher range of the prices. Check the skewness and kurtosis

# %%
#skewness and kurtosis
print("Skewness: %f" % df['price'].skew())
print("Kurtosis: %f" % df['price'].kurt())
# Out:
# Skewness: 4.937137
# Kurtosis: 38.971564

# %% [markdown]
# ## Plot with outliers removed

# %%
df_no_outliers = df[df.price < 15e6]
bins = range(int(df_no_outliers.price.min()),int(df_no_outliers.price.max()),500000)
plot_prices(df_no_outliers, bins)

# %% [markdown]
# ## Plot data on a slippy map to see locations of housing

# %%
m = folium.Map(location=(49.271554, -123.106738))
colors = ['gray', 'green','blue','red','orange', 'yellow']
colormap = StepColormap(colors=colors,vmin=5e5, vmax=10e6, caption='price')
m.add_child(colormap)
for i, latlng in enumerate(df['latlng']):
    price = df.loc[i, 'price']
    if latlng is not None and latlng != 'MISSING':
        if isinstance(latlng, str):
            lat, lng = latlng.replace('(','').replace(')','').split(',')
            latlng = (float(lat), float(lng))
        if not isinstance(latlng, tuple):
            continue
        display_html = pd.DataFrame(df.loc[i, :]).to_html()
        style = {'fillColor': colormap(price),
                'color' : colormap(price)}
        p = geojson.Point(coordinates=(latlng[1], latlng[0]), style=style)
#         html_info = pd.DataFrame(df.loc[i][:1]).to_html()
#         html_info = None
        html_info = '<li>Price: ${}</li><li>{}</li>'.format(df.loc[i, 'price'], df.loc[i, 'age'])
        m.add_child(folium.Marker(location=latlng, icon=folium.Icon(color='black', icon_color=colormap(price)), popup=folium.Popup(html=html_info)))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## As expected, we see higher pricing closer to downtown with lower prices on the outer regions

# %% [markdown]
# ## Next, let's see how some of the variables interact with the list price

# %%
#ssqft/saleprice
var = 'sqft'
sns.regplot(df[var], df['price'], )

# %%
var = 'bed'
sns.regplot(df[var], df['price'], )

# %%
var = 'bath'
sns.regplot(df[var], df['price'], )

# %%
corrmat = df.corr()
sns.heatmap(corrmat, vmax=1, square=True);

# %% [markdown]
# ## Analyze the categorical variables

# %%
df.columns
# Out:
# Index(['address', 'price', 'link', 'bed', 'bath', 'sqft', 'age',
#        'gross_taxes_2017', 'strata_maintenance_fees', 'area', 'sub_area',
#        'property_type', 'strata_type', 'listing_id', 'primary_broker',
#        'features', 'amenities', 'school_info', 'latlng'],
#       dtype='object')

# %%
print(df.area.unique())
print(df.sub_area.unique())
print(df.strata_type.unique())
print(df.property_type.unique())
# Out:
# ['Vancouver West' 'Vancouver East']
# ['False Creek' 'Downtown West' 'Yaletown' 'South Vancouver' 'Southlands'
#  'West End' 'Victoria East' 'Southwest Marine' 'South Granville'
#  'University (UBC)' 'Dunbar' 'Coal Harbour' 'Fairview' 'Collingwood'
#  'Champlain Heights' 'Downtown East' 'Killarney' 'Fraser East' 'Hastings'
#  'Hastings East' 'Kerrisdale' 'Fraserview East' 'Grandview East'
#  'Mount Pleasant East' 'Knight' 'Renfrew Heights' 'South Cambie'
#  'Quilchena' 'Oakridge' 'Marpole' 'MacKenzie Heights' 'Arbutus' 'Cambie'
#  'Main' 'Kitsilano' 'Renfrew' 'Point Grey' 'Mount Pleasant West'
#  'Shaughnessy']
# ['Freehold Strata' 'Leasehold prepaid-Strata' 'Freehold NonStrata'
#  'Shares in Co-operative' 'Leasehold prepaid-NonStrata'
#  'Leasehold not prepaid-NonStrata' 'Undivided Interest']
# ['Apt/Condo' 'House' 'Duplex' 'Townhouse' 'Land/Lot' 'Other' 'Triplex']

# %%
missing = df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %%
#age/saleprice
var = 'age'
sns.regplot(df[var], df['price'] )

# %%
vars_to_analyize = ['area', 'sub_area', 'property_type', 'strata_type']
for c in vars_to_analyize:
    df[c] = df[c].astype('category')
    if df[c].isnull().any():
        df[c] = df[c].cat.add_categories(['MISSING'])
        df[c] = df[c].fillna('MISSING')

def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)

f = pd.melt(df, id_vars=['price'], value_vars=vars_to_analyize)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, "value", "price")

# %% [markdown]
# ## Generate disparity map

# %%
from scipy import stats
import numpy as np
def anova(df):
    anv = pd.DataFrame()
    anv['feature'] = vars_to_analyize
    pvals = []
    for c in vars_to_analyize:
        samples = []
        for cls in df[c].unique():
            s = df[df[c] == cls]['price'].values
            samples.append(s)
        try:
            pval = stats.f_oneway(*samples)[1]
        except Exception as e:
            pval=None
        finally:
            pvals.append(pval)
    anv['pval'] = pvals
    return anv.sort_values('pval')

a = anova(df)
a['disparity'] = np.log(1./a['pval'].values)
sns.barplot(data=a, x='feature', y='disparity')
x=plt.xticks(rotation=90)

# %%
def pairplot(x, y, **kwargs):
    ax = plt.gca()
    ts = pd.DataFrame({'time': x, 'val': y})
    ts = ts.groupby('time').mean()
    ts.plot(ax=ax)
    plt.xticks(rotation=90)
    
f = pd.melt(df, id_vars=['price'], value_vars=vars_to_analyize)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(pairplot, "value", "price")

# %%
f.value.unique()
# Out:
# array(['Vancouver West', 'Vancouver East', 'False Creek', 'Downtown West',
#        'Yaletown', 'South Vancouver', 'Southlands', 'West End',
#        'Victoria East', 'Southwest Marine', 'South Granville',
#        'University (UBC)', 'Dunbar', 'Coal Harbour', 'Fairview',
#        'Collingwood', 'Champlain Heights', 'Downtown East', 'Killarney',
#        'Fraser East', 'Hastings', 'Hastings East', 'Kerrisdale',
#        'Fraserview East', 'Grandview East', 'Mount Pleasant East',
#        'Knight', 'Renfrew Heights', 'South Cambie', 'Quilchena',
#        'Oakridge', 'Marpole', 'MacKenzie Heights', 'Arbutus', 'Cambie',
#        'Main', 'Kitsilano', 'Renfrew', 'Point Grey', 'Mount Pleasant West',
#        'Shaughnessy', 'Apt/Condo', 'House', 'Duplex', 'Townhouse',
#        'Land/Lot', 'Other', 'Triplex', 'Freehold Strata',
#        'Leasehold prepaid-Strata', 'Freehold NonStrata',
#        'Shares in Co-operative', 'Leasehold prepaid-NonStrata',
#        'Leasehold not prepaid-NonStrata', 'Undivided Interest'], dtype=object)

# %% [markdown]
# ## Let's start with a basic univariate linear regressor using our most highly corellated variable as the dependant variable

# %% [markdown]
# # TODO:
# * ~~Scrape more data with more variables~~
# * select features
# * engineer features (dist to schools?, dist to city center?)
# * Train a basic linear regressor
# * Train a better model
# * Train a neural network
